# %%
import pandas as pd
import re

import_df = pd.read_excel('/Users/barganor/Downloads/Exports_and_Imports_by_Areas_and_Co.xlsx', index_col=0)
for col in import_df:
    if re.search('Q[1-4]$', col) and col != 'Country':
        import_df = import_df.drop(columns=[col], axis=1)
print(import_df.head())


# for code in import_df:
#     for i in import_df[code]:
#
#         if type(i) == str:
#             i = i.replace('r','')
#             i = i.replace(',', '')
#             i = float(i)
# Out:
#                        2000     2001     2002     2003     2004     2005  \
# Country
# Australia             144.1    145.0    118.0    127.4     74.3    115.7
# World               36802.0  33299.0  33106.3  34213.4  41101.1  44936.7
# Advanced Economies  28250.8  26032.8  25523.8  25008.4  29768.4  30396.9
# Euro Area           12255.5  11204.5  10850.8  11406.6  13553.3  13909.4
# Austria               116.9    119.4    128.2    153.8    204.1    202.9
#
#                        2006     2007     2008     2009  ...     2011     2012  \
# Country                                                 ...
# Australia             109.4    138.7    240.2    178.4  ...    152.0    131.8
# World               47738.5  56585.9  65144.6  47366.1  ...  73535.6  73120.6
# Advanced Economies  31354.3  37405.9  41162.6  31176.7  ...  45524.0  44921.1
# Euro Area           14162.9  16613.9  18310.9  14088.8  ...  20748.1  20305.8
# ...
